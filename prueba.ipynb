# %%
import pandas as pd
pd.read_json('tests/query_results/revenue_by_month_year.json')
# Out:
#     month_no month  Year2016    Year2017    Year2018
# 0          1   Jan      0.00    37632.57   969967.80
# 1          2   Feb      0.00   222270.75   853616.82
# 2          3   Mar      0.00   376833.72  1024851.95
# 3          4   Apr      0.00   299798.45  1274742.18
# 4          5   May      0.00   579280.43  1150528.93
# 5          6   Jun      0.00   489463.42  1141543.85
# 6          7   Jul      0.00   518115.19   925958.79
# 7          8   Aug      0.00   609180.34  1319737.66
# 8          9   Sep      0.00   652576.48    12875.18
# 9         10   Oct  34116.28   740570.40      347.95
# 10        11   Nov  10734.64   733047.33        0.00
# 11        12   Dec    960.85  1082600.69        0.00

# %%
import pandas as pd
pd.read_json('tests/query_results/real_vs_estimated_delivered_time.json')
# Out:
#     month_no month  Year2016_real_time  Year2017_real_time  \
# 0          1   Jan                 NaN           12.647044
# 1          2   Feb                 NaN           13.168825
# 2          3   Mar                 NaN           12.951184
# 3          4   Apr                 NaN           14.917913
# 4          5   May                 NaN           11.322363
# 5          6   Jun                 NaN           12.011573
# 6          7   Jul                 NaN           11.592732
# 7          8   Aug                 NaN           11.147125
# 8          9   Sep           54.813194           11.851007
# 9         10   Oct           19.600559           11.856700
# 10        11   Nov                 NaN           15.161132
# 11        12   Dec            4.693021           15.394919
#
#     Year2018_real_time  Year2016_estimated_time  Year2017_estimated_time  \
# 0            14.080563                      NaN                39.508831
# ...
